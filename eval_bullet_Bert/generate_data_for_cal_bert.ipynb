# %%
from pathlib import Path
import prepare_data_for_Bert as pdb
import importlib

# %%
importlib.reload(pdb)


try:
    BASE_DIR = Path(__file__).resolve().parent
except NameError:
    BASE_DIR = Path.cwd()
   

src_dir =  BASE_DIR  / "../data/no_split_bullet_first"
dst_dir = BASE_DIR / "../eval_bullet_Bert/tmp_data"

#src_prefix = "bullet_score_eval_"
#src_suffix = "_bullet_first_result.json"

#src_prefix = "bullet_score_eval_"
src_suffix = "_bullet_first_result.json"

dst_prefix = "data_for_cal_bert_"
dst_suffix = "_bullet_first.json"

pdb.prepare_json_for_bert(src_dir, dst_dir, src_suffix, dst_prefix, dst_suffix)
