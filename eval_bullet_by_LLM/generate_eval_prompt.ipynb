# %%
import evaluation_prompt_generation as epg
from pathlib import Path
import importlib

# %% [markdown]
# # use bullet-first file

# %%
importlib.reload(epg)  # reload after editing the file


models = ["llama", "mistral", "qwen"]
modes = ["2support", "2refute", "mix"]  

try:
    BASE_DIR = Path(__file__).resolve().parent
except NameError:
    BASE_DIR = Path.cwd()

src_dir = BASE_DIR / "../data/no_split_bullet_first"
dst_dir = BASE_DIR / "../eval_bullet_by_LLM/tmp_data"
#file_dir = "./data/no_split_bullet_first/"


file_list = []
for model in models:
    for mode in modes:
        src_filename = f"{model}_{mode}_bullet_first_result.json" 
        epg.generate_eval_prompt_file(src_dir, src_filename, dst_dir)
# Out:
# Prompts saved to: /Users/yingpei/Documents/kandidatDatalogi/project_Maria/code/EvidenceUtilization/eval_bullet_by_LLM/../eval_bullet_by_LLM/tmp_data/prompt_for_eval_bullets_llama_2support_bullet_first.json
# Prompts saved to: /Users/yingpei/Documents/kandidatDatalogi/project_Maria/code/EvidenceUtilization/eval_bullet_by_LLM/../eval_bullet_by_LLM/tmp_data/prompt_for_eval_bullets_llama_2refute_bullet_first.json
# Prompts saved to: /Users/yingpei/Documents/kandidatDatalogi/project_Maria/code/EvidenceUtilization/eval_bullet_by_LLM/../eval_bullet_by_LLM/tmp_data/prompt_for_eval_bullets_llama_mix_bullet_first.json
# Prompts saved to: /Users/yingpei/Documents/kandidatDatalogi/project_Maria/code/EvidenceUtilization/eval_bullet_by_LLM/../eval_bullet_by_LLM/tmp_data/prompt_for_eval_bullets_mistral_2support_bullet_first.json
# ...
