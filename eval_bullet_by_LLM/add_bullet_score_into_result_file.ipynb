# %%
import parse_bullets_score as pbs
from pathlib import Path
import importlib

# %%
importlib.reload(pbs)

try:
    BASE_DIR = Path(__file__).resolve().parent
except NameError:
    BASE_DIR = Path.cwd()
   

src_dir = BASE_DIR / "tmp_data"
dst_dir =  BASE_DIR  / "../data/no_split_bullet_first"


#src_prefix = "bullet_score_eval_"
#src_suffix = "_bullet_first_result.json"

src_prefix = "score_for_eval_bullets_"
src_suffix = "_bullet_first.json"

dst_suffix = "_bullet_first_result.json"
#score_for_eval_bullets_mistral_2refute_bullet_first.json

pbs.add_parsed_bullet_score_into_result(src_dir, dst_dir, src_prefix, src_suffix, dst_suffix)
# Out:
# src_dir is /Users/yingpei/Documents/kandidatDatalogi/project_Maria/code/EvidenceUtilization/eval_bullet_by_LLM/tmp_data
# Updated file: /Users/yingpei/Documents/kandidatDatalogi/project_Maria/code/EvidenceUtilization/eval_bullet_by_LLM/../data/no_split_bullet_first/llama_2support_bullet_first_result.json
# src_dir is /Users/yingpei/Documents/kandidatDatalogi/project_Maria/code/EvidenceUtilization/eval_bullet_by_LLM/tmp_data
# Updated file: /Users/yingpei/Documents/kandidatDatalogi/project_Maria/code/EvidenceUtilization/eval_bullet_by_LLM/../data/no_split_bullet_first/llama_2refute_bullet_first_result.json
# src_dir is /Users/yingpei/Documents/kandidatDatalogi/project_Maria/code/EvidenceUtilization/eval_bullet_by_LLM/tmp_data
# Updated file: /Users/yingpei/Documents/kandidatDatalogi/project_Maria/code/EvidenceUtilization/eval_bullet_by_LLM/../data/no_split_bullet_first/llama_mix_bullet_first_result.json
# ...
