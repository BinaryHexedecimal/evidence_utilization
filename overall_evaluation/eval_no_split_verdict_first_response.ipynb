# %%
import importlib

import plot_statistics as ps
import bullet_fk_calculation as bfc

# %%
def generate_source_file_name_lists(models, modes, suffix):
    merged_list = []
    for model in models:
        for mode in modes:
            filename = f"{model}_{mode}" + suffix
            merged_list.append(filename)
    return merged_list

# %%
models = ["llama", "mistral", "qwen"]

modes = ["2support", "2refute", "mix"]  

suffix = "_prob_result.json"

src_file_name_lst = generate_source_file_name_lists(models, modes, suffix)
print(src_file_name_lst)
# Out:
# ['llama_2support_prob_result.json', 'llama_2refute_prob_result.json', 'llama_mix_prob_result.json', 'mistral_2support_prob_result.json', 'mistral_2refute_prob_result.json', 'mistral_mix_prob_result.json', 'qwen_2support_prob_result.json', 'qwen_2refute_prob_result.json', 'qwen_mix_prob_result.json']

# %%
importlib.reload(ps)  # reload after editing the file

_dir = "../data/no_split_verdict_first/"

save_suffix = "verdict_first"
ps.plot_verdict_per_mode(_dir,src_file_name_lst, save_suffix)
ps.plot_internal_per_mode(_dir, src_file_name_lst, save_suffix)
ps.plot_confidence_per_mode(_dir, src_file_name_lst, save_suffix)
# Out:
# 5067
# 2205
# 1647

# %%
importlib.reload(ps)  # reload after editing the file


ps.plot_bullet_count_per_mode(_dir, src_file_name_lst, save_suffix)
ps.plot_bullet_length_per_mode(_dir, src_file_name_lst, save_suffix)
#ps.plot_nli_statistics(_dir, src_file_name_lst)
#ps.plot_fk_per_mode(_dir, src_file_name_lst)

# %%
importlib.reload(bfc) 
# calculate fk first
_dir = "../data/no_split_verdict_first/"
filename_suffix = "_prob_result.json"

#verdict_cnt_results = da.verdict_count(_dir, filename_suffix)
#importlib.reload(ba) 
#_dir = "./data/no_split_bullet_first/"
#filename_suffix = "_bullet_first_result.json"
bfc.bullet_fk_generate(_dir, filename_suffix)
# Out:
# Processing: ../data/no_split_verdict_first/llama_2support_prob_result.json
# Updated original file → ../data/no_split_verdict_first/llama_2support_prob_result.json
#
# Processing: ../data/no_split_verdict_first/mistral_2support_prob_result.json
# Updated original file → ../data/no_split_verdict_first/mistral_2support_prob_result.json
#
# Processing: ../data/no_split_verdict_first/qwen_2support_prob_result.json
# Updated original file → ../data/no_split_verdict_first/qwen_2support_prob_result.json
#
# Processing: ../data/no_split_verdict_first/llama_2refute_prob_result.json
# Updated original file → ../data/no_split_verdict_first/llama_2refute_prob_result.json
#
# Processing: ../data/no_split_verdict_first/mistral_2refute_prob_result.json
# Updated original file → ../data/no_split_verdict_first/mistral_2refute_prob_result.json
#
# Processing: ../data/no_split_verdict_first/qwen_2refute_prob_result.json
# Updated original file → ../data/no_split_verdict_first/qwen_2refute_prob_result.json
#
# Processing: ../data/no_split_verdict_first/llama_mix_prob_result.json
# Updated original file → ../data/no_split_verdict_first/llama_mix_prob_result.json
#
# Processing: ../data/no_split_verdict_first/mistral_mix_prob_result.json
# Updated original file → ../data/no_split_verdict_first/mistral_mix_prob_result.json
#
# Processing: ../data/no_split_verdict_first/qwen_mix_prob_result.json
# Updated original file → ../data/no_split_verdict_first/qwen_mix_prob_result.json

# %%
importlib.reload(ps)  # reload after editing the file

#ps.plot_nli_statistics(_dir, src_file_name_lst)



ps.plot_fk_per_mode(_dir, src_file_name_lst, save_suffix)
# Out:
# Loading: ../data/no_split_verdict_first/llama_2support_prob_result.json
# Loading: ../data/no_split_verdict_first/llama_2refute_prob_result.json
# Loading: ../data/no_split_verdict_first/llama_mix_prob_result.json
# Loading: ../data/no_split_verdict_first/mistral_2support_prob_result.json
# Loading: ../data/no_split_verdict_first/mistral_2refute_prob_result.json
# Loading: ../data/no_split_verdict_first/mistral_mix_prob_result.json
# Loading: ../data/no_split_verdict_first/qwen_2support_prob_result.json
# Loading: ../data/no_split_verdict_first/qwen_2refute_prob_result.json
# Loading: ../data/no_split_verdict_first/qwen_mix_prob_result.json
