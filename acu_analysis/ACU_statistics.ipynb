# %%
import importlib
import acu as acu

# %% [markdown]
# ## verdict only ##

# %%
importlib.reload(acu)  # reload after editing the file


models = ["llama", "mistral", "qwen"]
modes = ["2support", "2refute", "mix"]

    
#verdict_only
_dir = "../data/no_split_verdict_only/"
_suffix = "_only_verdict_result.json"  
save_folder = "verdict_only"
save_file_suffix = "verdict_only"
title_suffix = "V_prompt"
    
for model in models:
    for mode in modes:
        acu.draw_single_p(model, mode, _dir, _suffix, save_folder, title_suffix, save_file_suffix)

# %%
importlib.reload(acu)  # reload after editing the file
for mode in modes:
    #df_long = acu.gen_long_df(models, mode, _dir, _suffix, save_folder, save_file_suffix)
    df_long = acu.gen_long_df(models, mode, _dir, _suffix)
    acu.plot_p_boxplots(df_long, mode, save_folder, save_file_suffix)

# %%
importlib.reload(acu)  # reload after editing the file
for model in models:
    for mode in modes:
        acu.draw_single_acu(model, mode, _dir, _suffix, save_folder, title_suffix, save_file_suffix)
# Out:
# ACU written into: ../data/no_split_verdict_only/llama_2support_only_verdict_result.json
# ACU written into: ../data/no_split_verdict_only/llama_2refute_only_verdict_result.json
# [SKIP] ACU undefined for mix: llama, verdict_only
# ACU written into: ../data/no_split_verdict_only/mistral_2support_only_verdict_result.json
# ACU written into: ../data/no_split_verdict_only/mistral_2refute_only_verdict_result.json
# [SKIP] ACU undefined for mix: mistral, verdict_only
# ACU written into: ../data/no_split_verdict_only/qwen_2support_only_verdict_result.json
# ACU written into: ../data/no_split_verdict_only/qwen_2refute_only_verdict_result.json
# [SKIP] ACU undefined for mix: qwen, verdict_only

# %%
importlib.reload(acu) 
acu.draw_acu_summary("basic", models, modes, _dir, _suffix, save_folder, save_file_suffix)
acu.draw_acu_summary("internal", models, modes, _dir, _suffix, save_folder, save_file_suffix)

acu.draw_acu_summary_combined(models, modes, _dir, _suffix, save_folder, save_file_suffix)
# Out:
# acu summary--------[SKIP] ACU undefined for mix: verdict_only
# acu summary--------[SKIP] ACU undefined for mix: verdict_only

# %% [markdown]
# ## verdict first     ##

# %%
importlib.reload(acu)  # reload after editing the file

#verdict_first
_dir = "../data/no_split_verdict_first/"
_suffix = "_prob_result.json"
save_folder = "verdict_first"
save_file_suffix = "verdict_first"
title_suffix = "VCBI_prompt"
    
for model in models:
    for mode in modes:
        acu.draw_single_p(model, mode, _dir, _suffix, save_folder,title_suffix, save_file_suffix)

# %%
for mode in modes:
    #df_long = acu.gen_long_df(models, mode, _dir, _suffix, save_folder, save_file_suffix)
    df_long = acu.gen_long_df(models, mode, _dir, _suffix)
    acu.plot_p_boxplots(df_long, mode, save_folder, save_file_suffix)

# %%
importlib.reload(acu)  # reload after editing the file
for model in models:
    for mode in modes:
        acu.draw_single_acu(model, mode, _dir, _suffix, save_folder, title_suffix, save_file_suffix)

acu.draw_acu_summary("basic", models, modes, _dir, _suffix, save_folder, save_file_suffix)
acu.draw_acu_summary("internal", models, modes, _dir, _suffix, save_folder, save_file_suffix)

acu.draw_acu_summary_combined(models, modes, _dir, _suffix, save_folder, save_file_suffix)
# Out:
# ACU written into: ../data/no_split_verdict_first/llama_2support_prob_result.json
# ACU written into: ../data/no_split_verdict_first/llama_2refute_prob_result.json
# [SKIP] ACU undefined for mix: llama, verdict_first
# ACU written into: ../data/no_split_verdict_first/mistral_2support_prob_result.json
# ACU written into: ../data/no_split_verdict_first/mistral_2refute_prob_result.json
# [SKIP] ACU undefined for mix: mistral, verdict_first
# ACU written into: ../data/no_split_verdict_first/qwen_2support_prob_result.json
# ACU written into: ../data/no_split_verdict_first/qwen_2refute_prob_result.json
# [SKIP] ACU undefined for mix: qwen, verdict_first
# acu summary--------[SKIP] ACU undefined for mix: verdict_first
# acu summary--------[SKIP] ACU undefined for mix: verdict_first

# %% [markdown]
# ## verdict_confidence ##

# %%
importlib.reload(acu)  # reload after editing the file

#verdict_conf
_dir = "../data/no_split_verdict_conf/"
_suffix = "_verdict_and_conf_result.json"
save_folder = "verdict_conf"
save_file_suffix = "verdict_and_confidence"
title_suffix = "VC_prompt"
    
for model in models:
    for mode in modes:
        acu.draw_single_p(model, mode, _dir, _suffix, save_folder, title_suffix, save_file_suffix)

# %%
for mode in modes:
    df_long = acu.gen_long_df(models, mode, _dir, _suffix)
    acu.plot_p_boxplots(df_long, mode, save_folder, save_file_suffix)

# %%
importlib.reload(acu)  # reload after editing the file

for model in models:
    for mode in modes:
        acu.draw_single_acu(model, mode, _dir, _suffix, save_folder, title_suffix, save_file_suffix)

acu.draw_acu_summary("basic", models, modes, _dir, _suffix, save_folder, save_file_suffix)
acu.draw_acu_summary("internal", models, modes, _dir, _suffix, save_folder, save_file_suffix)
acu.draw_acu_summary_combined(models, modes, _dir, _suffix, save_folder, save_file_suffix)
# Out:
# ACU written into: ../data/no_split_verdict_conf/llama_2support_verdict_and_conf_result.json
# ACU written into: ../data/no_split_verdict_conf/llama_2refute_verdict_and_conf_result.json
# [SKIP] ACU undefined for mix: llama, verdict_and_confidence
# ACU written into: ../data/no_split_verdict_conf/mistral_2support_verdict_and_conf_result.json
# ACU written into: ../data/no_split_verdict_conf/mistral_2refute_verdict_and_conf_result.json
# [SKIP] ACU undefined for mix: mistral, verdict_and_confidence
# ACU written into: ../data/no_split_verdict_conf/qwen_2support_verdict_and_conf_result.json
# ACU written into: ../data/no_split_verdict_conf/qwen_2refute_verdict_and_conf_result.json
# [SKIP] ACU undefined for mix: qwen, verdict_and_confidence
# acu summary--------[SKIP] ACU undefined for mix: verdict_and_confidence
# acu summary--------[SKIP] ACU undefined for mix: verdict_and_confidence
