# %%
import parse_response_verdict_and_bullet as pvb
import importlib
from pathlib import Path

# %%
importlib.reload(pvb)  

models = ["llama", "mistral", "qwen"]
modes = ["2support", "1refute", "mix"]  


try:
    BASE_DIR = Path(__file__).resolve().parent
except NameError:
    BASE_DIR = Path.cwd()

file_dir = "../data/split_by_verdict/true"
file_suffix = "_true_bullet_first_result.json"
pvb.parse_and_update_json(BASE_DIR, modes, models, file_dir, file_suffix)
# Out:
# Updated & overwritten: /Users/yingpei/Documents/kandidatDatalogi/project_Maria/code/EvidenceUtilization/parse_response/../data/split_by_verdict/true/llama_2support_true_bullet_first_result.json
# [WARN] /Users/yingpei/Documents/kandidatDatalogi/project_Maria/code/EvidenceUtilization/parse_response/../data/split_by_verdict/true/mistral_2support_true_bullet_first_result.json | item 57 | response_claim unparsable verdict
# Updated & overwritten: /Users/yingpei/Documents/kandidatDatalogi/project_Maria/code/EvidenceUtilization/parse_response/../data/split_by_verdict/true/mistral_2support_true_bullet_first_result.json
# [WARN] /Users/yingpei/Documents/kandidatDatalogi/project_Maria/code/EvidenceUtilization/parse_response/../data/split_by_verdict/true/qwen_2support_true_bullet_first_result.json | item 6 | response_basic unparsable verdict
# Updated & overwritten: /Users/yingpei/Documents/kandidatDatalogi/project_Maria/code/EvidenceUtilization/parse_response/../data/split_by_verdict/true/qwen_2support_true_bullet_first_result.json
# Updated & overwritten: /Users/yingpei/Documents/kandidatDatalogi/project_Maria/code/EvidenceUtilization/parse_response/../data/split_by_verdict/true/llama_1refute_true_bullet_first_result.json
# Updated & overwritten: /Users/yingpei/Documents/kandidatDatalogi/project_Maria/code/EvidenceUtilization/parse_response/../data/split_by_verdict/true/mistral_1refute_true_bullet_first_result.json
# Updated & overwritten: /Users/yingpei/Documents/kandidatDatalogi/project_Maria/code/EvidenceUtilization/parse_response/../data/split_by_verdict/true/qwen_1refute_true_bullet_first_result.json
# Updated & overwritten: /Users/yingpei/Documents/kandidatDatalogi/project_Maria/code/EvidenceUtilization/parse_response/../data/split_by_verdict/true/llama_mix_true_bullet_first_result.json
# Updated & overwritten: /Users/yingpei/Documents/kandidatDatalogi/project_Maria/code/EvidenceUtilization/parse_response/../data/split_by_verdict/true/mistral_mix_true_bullet_first_result.json
# Updated & overwritten: /Users/yingpei/Documents/kandidatDatalogi/project_Maria/code/EvidenceUtilization/parse_response/../data/split_by_verdict/true/qwen_mix_true_bullet_first_result.json

# %%
# pvfl.parse_bullets("maybe Confidence score: 80 Bullets: -- Qaa is mentioned as a town in Baalbek-Hermel Governorate, Lebanon. -- The town has a population of around 500 Lebanese Maronites. -- There have been instances where the Syrian army has invaded Lebanon and targeted Qaa, such as in 2012 and 2016. -- The town is located near the border with Syria, and there is a lack of clear distinction between Lebanese and Syrian territories. -- The town has received aid from international organizations like the UNDP, which has funded solar energy projects in the area. -- The town's residents face economic challenges, with many earning less than $100 per month. Internal knowledge: false")
