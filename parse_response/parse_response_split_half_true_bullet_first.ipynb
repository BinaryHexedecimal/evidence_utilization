# %%
import parse_response_verdict_and_bullet as pvb
import importlib
from pathlib import Path

# %%
importlib.reload(pvb)  

models = ["llama", "mistral", "qwen"]
modes = ["2support", "2refute", "mix"]  


try:
    BASE_DIR = Path(__file__).resolve().parent
except NameError:
    BASE_DIR = Path.cwd()

file_dir = "../data/split_by_verdict/half_true"
file_suffix = "_half_true_bullet_first_result.json"
pvb.parse_and_update_json(BASE_DIR, modes, models, file_dir, file_suffix)
# Out:
# [WARN] /Users/yingpei/Documents/kandidatDatalogi/project_Maria/code/EvidenceUtilization/parse_response/../data/split_by_verdict/half_true/llama_2support_half_true_bullet_first_result.json | item 0 | response_internal unparsable verdict
# [WARN] /Users/yingpei/Documents/kandidatDatalogi/project_Maria/code/EvidenceUtilization/parse_response/../data/split_by_verdict/half_true/llama_2support_half_true_bullet_first_result.json | item 4 | response_basic unparsable verdict
# [WARN] /Users/yingpei/Documents/kandidatDatalogi/project_Maria/code/EvidenceUtilization/parse_response/../data/split_by_verdict/half_true/llama_2support_half_true_bullet_first_result.json | item 4 | response_internal unparsable verdict
# [WARN] /Users/yingpei/Documents/kandidatDatalogi/project_Maria/code/EvidenceUtilization/parse_response/../data/split_by_verdict/half_true/llama_2support_half_true_bullet_first_result.json | item 6 | response_basic unparsable verdict
# ...

# %%
# pvfl.parse_bullets("maybe Confidence score: 80 Bullets: -- Qaa is mentioned as a town in Baalbek-Hermel Governorate, Lebanon. -- The town has a population of around 500 Lebanese Maronites. -- There have been instances where the Syrian army has invaded Lebanon and targeted Qaa, such as in 2012 and 2016. -- The town is located near the border with Syria, and there is a lack of clear distinction between Lebanese and Syrian territories. -- The town has received aid from international organizations like the UNDP, which has funded solar energy projects in the area. -- The town's residents face economic challenges, with many earning less than $100 per month. Internal knowledge: false")

# %%
#importlib.reload(ba) 
#_dir = "./data/no_split_bullet_first/"
#filename_suffix = "_bullet_first_result.json"
#ba.bullet_fk_generate(_dir, filename_suffix)

# %%
#da.plot_single_mode_verdict_cnt("mix", verdict_cnt_results, "bullet_first")

# %%
#importlib.reload(pbs)

#_dir = "./data/no_split_bullet_first/"

#prefix = "bullet_score_eval_"
#suffix = "_bullet_first_result.json"



#pbs.add_parsed_score_into_json(_dir, prefix, suffix)
