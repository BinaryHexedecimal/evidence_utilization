# %%
import parse_response_verdict_and_bullet as pvb
import importlib
from pathlib import Path

# %%
importlib.reload(pvb)  

models = ["llama", "mistral", "qwen"]
modes = ["2support", "2refute", "mix"]  


try:
    BASE_DIR = Path(__file__).resolve().parent
except NameError:
    BASE_DIR = Path.cwd()

file_dir = "../data/no_split_inverse_bullet_first"
file_suffix = "_inverse_bullet_first_result.json"
pvb.parse_and_update_json(BASE_DIR,  modes, models, file_dir, file_suffix)
# Out:
# [WARN] /Users/yingpei/Documents/kandidatDatalogi/project_Maria/code/EvidenceUtilization/parse_response/../data/no_split_inverse_bullet_first/llama_2support_inverse_bullet_first_result.json | item 128 | response_basic unparsable verdict
# [WARN] /Users/yingpei/Documents/kandidatDatalogi/project_Maria/code/EvidenceUtilization/parse_response/../data/no_split_inverse_bullet_first/llama_2support_inverse_bullet_first_result.json | item 128 | response_internal unparsable verdict
# [WARN] /Users/yingpei/Documents/kandidatDatalogi/project_Maria/code/EvidenceUtilization/parse_response/../data/no_split_inverse_bullet_first/llama_2support_inverse_bullet_first_result.json | item 145 | response_basic unparsable verdict
# [WARN] /Users/yingpei/Documents/kandidatDatalogi/project_Maria/code/EvidenceUtilization/parse_response/../data/no_split_inverse_bullet_first/llama_2support_inverse_bullet_first_result.json | item 145 | response_internal unparsable verdict
# ...

# %%
#importlib.reload(ba) 
#_dir = "./data/no_split_inverse_bullet_first/"
#filename_suffix = "_inverse_bullet_first_result.json"
#ba.bullet_fk_generate(_dir, filename_suffix)

# %%
#importlib.reload(da) 

#_dir = "./data/no_split_bullet_first/"
#filename_suffix = "_bullet_first_result.json"

#verdict_cnt_results = da.verdict_count(_dir, filename_suffix)

#da.plot_single_mode_verdict_cnt("2support", verdict_cnt_results, "bullet_first")
