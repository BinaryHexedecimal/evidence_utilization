# %%
import parse_response_verdict_only as pvo
import importlib
from pathlib import Path

# %%
importlib.reload(pvo)  

try:
    BASE_DIR = Path(__file__).resolve().parent
except NameError:
    BASE_DIR = Path.cwd()
_dir = BASE_DIR / "../data/no_split_verdict_conf"


models = ["llama", "mistral", "qwen"]
modes = ["2support", "2refute", "mix"]  
suffix = "_verdict_and_conf_result.json" 


pvo.parse_and_update_json(_dir, modes, models, suffix, conf = True)
# Out:
# Updated & overwritten: /Users/yingpei/Documents/kandidatDatalogi/project_Maria/code/EvidenceUtilization/parse_response/../data/no_split_verdict_conf/llama_2support_verdict_and_conf_result.json
# Updated & overwritten: /Users/yingpei/Documents/kandidatDatalogi/project_Maria/code/EvidenceUtilization/parse_response/../data/no_split_verdict_conf/mistral_2support_verdict_and_conf_result.json
# Updated & overwritten: /Users/yingpei/Documents/kandidatDatalogi/project_Maria/code/EvidenceUtilization/parse_response/../data/no_split_verdict_conf/qwen_2support_verdict_and_conf_result.json
# Updated & overwritten: /Users/yingpei/Documents/kandidatDatalogi/project_Maria/code/EvidenceUtilization/parse_response/../data/no_split_verdict_conf/llama_2refute_verdict_and_conf_result.json
# Updated & overwritten: /Users/yingpei/Documents/kandidatDatalogi/project_Maria/code/EvidenceUtilization/parse_response/../data/no_split_verdict_conf/mistral_2refute_verdict_and_conf_result.json
# ...
