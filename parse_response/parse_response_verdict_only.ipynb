# %%
import parse_response_verdict_only as pvo
import importlib
from pathlib import Path

# %%
importlib.reload(pvo)  # reload after editing the file

try:
    BASE_DIR = Path(__file__).resolve().parent
except NameError:
    BASE_DIR = Path.cwd()
_dir = BASE_DIR / "../data/no_split_verdict_only"

models = ["llama", "mistral", "qwen"]
modes = ["2support", "2refute", "mix"]  
suffix = "_only_verdict_result.json" 

pvo.parse_and_update_json(_dir, modes, models, suffix)
# Out:
# Updated & overwritten: /Users/yingpei/Documents/kandidatDatalogi/project_Maria/code/EvidenceUtilization/parse_response/../data/no_split_verdict_only/llama_2support_only_verdict_result.json
# Updated & overwritten: /Users/yingpei/Documents/kandidatDatalogi/project_Maria/code/EvidenceUtilization/parse_response/../data/no_split_verdict_only/mistral_2support_only_verdict_result.json
# Updated & overwritten: /Users/yingpei/Documents/kandidatDatalogi/project_Maria/code/EvidenceUtilization/parse_response/../data/no_split_verdict_only/qwen_2support_only_verdict_result.json
# Updated & overwritten: /Users/yingpei/Documents/kandidatDatalogi/project_Maria/code/EvidenceUtilization/parse_response/../data/no_split_verdict_only/llama_2refute_only_verdict_result.json
# Updated & overwritten: /Users/yingpei/Documents/kandidatDatalogi/project_Maria/code/EvidenceUtilization/parse_response/../data/no_split_verdict_only/mistral_2refute_only_verdict_result.json
# ...
