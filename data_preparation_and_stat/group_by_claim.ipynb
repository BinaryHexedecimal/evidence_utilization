# %%
import importlib
#import pandas as pd
#import os
import claims_preparation as cp

# %%
# no split
importlib.reload(cp)  # reload after editing the file

src_path = '../data/DruidData/druid.tsv'
dst_path = '../data/flatten_claims.csv'
cp.group_by_claim_and_flatten_claims(src_path, dst_path)
# Out:
# After discarding Non-relevant evidence, 5399 evidence remain in raw data.
# Only supports and refutes evidence remain, grouped by claim_id, 1171 claims remains
# Saved wide format to ../data/flatten_claims.csv.

# %%
#split by factcheck verdict
importlib.reload(cp)  # reload after editing the file

src_path = '../data/DruidData/druid.tsv'
dst_dir = '../data/'
cp.split_by_factcheck_verdict_and_flatten(src_path, dst_dir)
# Out:
# Raw data has 5490 rows
# After discarding borderline claims and Non-relevant, 4417 evidence remain in raw data.
# Only supports and refutes evidence remain, in total 2340 rows
# Grouped by claim_id, 974 claims remains
# Groupped by factcheck verdict:
# True claims: 151, False claims: 770, Half True claims: 53
#
#  Done! Files are split and saved.
